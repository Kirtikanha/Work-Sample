# %%
import pandas as pd
data = pd.read_csv("Iris.csv")
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import numpy as np
c1 = np.array([5.1, 3.5, 1.4, 0.2])
c2 = np.array([6.3, 3.3, 4.7, 1.6])

# %%
A = data.iloc[:, :4]
A
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
d1= np.sqrt((c1[0] - A[["SepalLengthCm"]].values)**2 + (c1[1] - A[["SepalWidthCm"]].values)**2 +(A[["PetalLengthCm"]].values - c1[2])**2 + (A[["PetalWidthCm"]].values - c1[3])**2)
d2= np.sqrt((c2[0] - A[["SepalLengthCm"]].values)**2 + (c2[1] - A[["SepalWidthCm"]].values)**2 +(A[["PetalLengthCm"]].values - c2[2])**2 + (A[["PetalWidthCm"]].values - c2[3])**2)
for i in d1:
    print(i, end=",")
# Out:
# [0.],[0.53851648],[0.50990195],[0.64807407],[0.14142136],[0.6164414],[0.51961524],[0.17320508],[0.92195445],[0.46904158],[0.37416574],[0.37416574],[0.59160798],[0.99498744],[0.88317609],[1.1045361],[0.54772256],[0.1],[0.74161985],[0.33166248],[0.43588989],[0.3],[0.64807407],[0.46904158],[0.59160798],[0.54772256],[0.31622777],[0.14142136],[0.14142136],[0.53851648],[0.53851648],[0.38729833],[0.6244998],[0.80622577],[0.46904158],[0.37416574],[0.41231056],[0.46904158],[0.8660254],[0.14142136],[0.17320508],[1.34907376],[0.76811457],[0.45825757],[0.6164414],[0.59160798],[0.36055513],[0.58309519],[0.3],[0.2236068],[4.00374824],[3.61662826],[4.16413256],[3.09354166],[3.79209705],[3.41613817],[3.78549865],[2.34520788],[3.74966665],[2.88790582],[2.70370117],[3.22800248],[3.14642654],[3.7],[2.58069758],[3.62767143],[3.43511281],[3.00998339],[3.76828874],[2.88270706],[3.85356977],[3.0757113],[4.04722127],[3.65786823],[3.41613817],[3.59722115],[4.04722127],[4.24499706],[3.53128872],[2.49399278],[
# ...

# %%
A["D1"]= np.array(d1)
A["D2"]= np.array(d2)
A
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm        D1  \
# 0              5.1           3.5            1.4           0.2  0.000000
# 1              4.9           3.0            1.4           0.2  0.538516
# 2              4.7           3.2            1.3           0.2  0.509902
# 3              4.6           3.1            1.5           0.2  0.648074
# 4              5.0           3.6            1.4           0.2  0.141421
# ..             ...           ...            ...           ...       ...
# 145            6.7           3.0            5.2           2.3  4.654031
# 146            6.3           2.5            5.0           1.9  4.276681
# 147            6.5           3.0            5.2           2.0  4.459821
# 148            6.2           3.4            5.4           2.3  4.650806
# 149            5.9           3.0            5.1           1.8  4.140048
#
#            D2
# 0    3.785499
# 1    3.860052
# 2    4.011234
# 3    3.889730
# 4    3.824918
# ...

# %%
df = pd.DataFrame({'D1': [[0.], [0.53851648], [0.50990195], [0.64807407], [0.14142136], [0.6164414], [0.51961524], [0.17320508], [0.92195445], [0.46904158], [0.37416574], [0.37416574], [0.59160798], [0.99498744], [0.88317609], [1.1045361], [0.54772256], [0.1], [0.74161985], [0.33166248], [0.43588989], [0.3], [0.64807407], [0.46904158], [0.59160798], [0.54772256], [0.31622777], [0.14142136], [0.14142136], [0.53851648], [0.53851648], [0.38729833], [0.6244998], [0.80622577], [0.46904158], [0.37416574], [0.41231056], [0.46904158], [0.8660254], [0.14142136], [0.17320508], [1.34907376], [0.76811457], [0.45825757], [0.6164414], [
#view DataFrame
print(df)
# Out:
#                D1            D2
# 0           [0.0]  [3.78549865]
# 1    [0.53851648]  [3.86005181]
# 2    [0.50990195]  [4.01123422]
# 3    [0.64807407]  [3.88973007]
# 4    [0.14142136]   [3.8249183]
# ..            ...           ...
# 145  [4.65403051]  [0.99498744]
# 146  [4.27668096]  [0.90553851]
# 147  [4.45982062]  [0.73484692]
# 148  [4.65080638]         [1.0]
# 149  [4.14004831]  [0.67082039]
#
# [150 rows x 2 columns]

# %%
Minimum_value = df.min(axis=1)
A["Minimum_value"] = df.min(axis=1)
A
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm        D1  \
# 0              5.1           3.5            1.4           0.2  0.000000
# 1              4.9           3.0            1.4           0.2  0.538516
# 2              4.7           3.2            1.3           0.2  0.509902
# 3              4.6           3.1            1.5           0.2  0.648074
# 4              5.0           3.6            1.4           0.2  0.141421
# ..             ...           ...            ...           ...       ...
# 145            6.7           3.0            5.2           2.3  4.654031
# 146            6.3           2.5            5.0           1.9  4.276681
# 147            6.5           3.0            5.2           2.0  4.459821
# 148            6.2           3.4            5.4           2.3  4.650806
# 149            5.9           3.0            5.1           1.8  4.140048
#
#            D2 Minimum_value
# 0    3.785499         [0.0]
# 1    3.860052  [0.53851648]
# ...

# %%
A.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          D1  \
# count     150.000000    150.000000     150.000000    150.000000  150.000000
# mean        5.843333      3.054000       3.758667      1.198667    2.890800
# std         0.828066      0.433594       1.764420      0.763161    1.875543
# min         4.300000      2.000000       1.000000      0.100000    0.000000
# 25%         5.100000      2.800000       1.600000      0.300000    0.618456
# 50%         5.800000      3.000000       4.350000      1.300000    3.378445
# 75%         6.400000      3.300000       5.100000      1.800000    4.268760
# max         7.900000      4.400000       6.900000      2.500000    6.498461
#
#                D2
# count  150.000000
# mean     2.022918
# std      1.332178
# min      0.000000
# 25%      0.927362
# 50%      1.442183
# 75%      3.643487
# max      4.393177

# %%
flag = 0
for i in Minimum_value:
    for j in d1:
        if (i == j):
            flag = 1
            break
if flag:
    x = sum(j)/len(j)
    print("Average of Cluster C1:", x)
else:
    print("Not equal")
# Out:
# Average of Cluster C1: 4.1400483088968905

# %%
print(Minimum_value)
# Out:
# 0             [0.0]
# 1      [0.53851648]
# 2      [0.50990195]
# 3      [0.64807407]
# 4      [0.14142136]
#            ...
# 145    [0.99498744]
# 146    [0.90553851]
# 147    [0.73484692]
# 148           [1.0]
# 149    [0.67082039]
# Length: 150, dtype: object

# %%
np_array_data = np.array(A)
np_array_data
# Out:
# array([[5.1, 3.5, 1.4, ..., 0.0, 3.7854986461495406, list([0.0])],
#        [4.9, 3.0, 1.4, ..., 0.5385164807134502, 3.8600518131237567,
#         list([0.53851648])],
#        [4.7, 3.2, 1.3, ..., 0.509901951359278, 4.011234224026316,
#         list([0.50990195])],
#        ...,
#        [6.5, 3.0, 5.2, ..., 4.459820624195552, 0.7348469228349533,
#         list([0.73484692])],
#        [6.2, 3.4, 5.4, ..., 4.650806381693394, 0.9999999999999999,
#         list([1.0])],
#        [5.9, 3.0, 5.1, ..., 4.1400483088968905, 0.6708203932499363,
#         list([0.67082039])]], dtype=object)
